# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.18.1-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  23.76 MB/s
# geopy-1.18.1-p 100% |################################| Time: 0:00:00  37.20 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  54.29 MB/s
# ...

# %%
CLIENT_ID = 'RUWENN41AQNZCAN1GGZU5DOAWFN2BGP1CDMYS42EOWHV1UKI' # your Foursquare ID
CLIENT_SECRET = 'AVQNOUSATC1LPMERL4EESPIYPH1GLXSKHAJVGVFTTAV4SHY1' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 10000
print('Your credentails:')
print('CLIENT_ID:' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID:RUWENN41AQNZCAN1GGZU5DOAWFN2BGP1CDMYS42EOWHV1UKI
# CLIENT_SECRET:AVQNOUSATC1LPMERL4EESPIYPH1GLXSKHAJVGVFTTAV4SHY1

# %%
address = 'Nevsky prospect, St. Petersburg, Russian Federation'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 59.9356467 30.3235057

# %%
search_query = 'Pub'
radius = 15000
print(search_query + ' .... OK!')
# Out:
# Pub .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RUWENN41AQNZCAN1GGZU5DOAWFN2BGP1CDMYS42EOWHV1UKI&client_secret=AVQNOUSATC1LPMERL4EESPIYPH1GLXSKHAJVGVFTTAV4SHY1&ll=59.9356467,30.3235057&v=20180604&query=Pub&radius=15000&limit=10000'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c6674ccdb04f505a60c7d38'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4c210d43132f0f47f3aca796',
#     'location': {'address': 'Невский просп., 22',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 81,
#      'formattedAddress': ['Невский просп., 22',
#       '191186, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.936261,
#        'lng': 30.322727}],
#      'lat': 59.936261,
#      'lng': 30.322727,
#      'postalCode': '191186',
#      'state': 'Санкт-Петербург'},
#     'name': 'Tower Pub',
#     'referralId': 'v-1550218444'},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'icon': {'prefix': 'https://ss3.4sqi.net/img...    False
# 1  [{'icon': {'prefix': 'https://ss3.4sqi.net/img...    False
# 2  [{'icon': {'prefix': 'https://ss3.4sqi.net/img...    False
# 3  [{'icon': {'prefix': 'https://ss3.4sqi.net/img...    False
# 4  [{'icon': {'prefix': 'https://ss3.4sqi.net/img...    False
#
#                          id     location.address location.cc    location.city  \
# 0  4c210d43132f0f47f3aca796   Невский просп., 22          RU  Санкт-Петербург
# 1  4cb9fa88bac93704486de87c   Невский просп., 38          RU  Санкт-Петербург
# 2  4bbb6cbb1261d13a51a9eb98     Шведский пер., 2          RU  Санкт-Петербург
# 3  4b9c0540f964a520974136e3  ул. Рубинштейна, 36          RU  Санкт-Петербург
# 4  4bc8997915a7ef3bfe6a7bda     Казанская ул., 5          RU  Санкт-Петербург
#
#   location.country  location.crossStreet  location.distance  \
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name             categories  \
# 0                                           Tower Pub                    Pub
# 1                                            Rock-Pub                    Pub
# 2                               James Cook Pub & Cafe                    Pub
# 3                               Mollie's Pub / Моллис                    Pub
# 4                                      The Office Pub                    Pub
# 5                                Shilling British Pub                    Pub
# 6                                          London Pub                    Pub
# 7                          Бристоль паб / Bristol Pub                    Pub
# 8                         Спорт Паб 84 / Sport pub 84             Sports Bar
# 9                                          Oliver Pub                    Pub
# 10                                          Tower Pub                    Pub
# ...

# %%
dataframe_filtered.name
# Out:
# 0                                             Tower Pub
# 1                                              Rock-Pub
# 2                                 James Cook Pub & Cafe
# 3                                 Mollie's Pub / Моллис
# 4                                        The Office Pub
# 5                                  Shilling British Pub
# 6                                            London Pub
# 7                            Бристоль паб / Bristol Pub
# 8                           Спорт Паб 84 / Sport pub 84
# 9                                            Oliver Pub
# 10                                            Tower Pub
# 11    City Pub Crawl - Saint - Petersburg / Тур по б...
# 12                                          O'Hooligans
# 13                                         Corleone Pub
# 14                                   Secret Service Pub
# 15                                       Dog's Nose Pub
# 16                                      Rugby House Pub
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Nevskyy Prospect

# add a red circle marker to represent the St. Petrsburg
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Pubs restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4c210d43132f0f47f3aca796' # ID of Tower Pub
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4c210d43132f0f47f3aca796?client_id=RUWENN41AQNZCAN1GGZU5DOAWFN2BGP1CDMYS42EOWHV1UKI&client_secret=AVQNOUSATC1LPMERL4EESPIYPH1GLXSKHAJVGVFTTAV4SHY1&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['verified', 'hereNow', 'hours', 'beenHere', 'tips', 'dislike', 'popular', 'url', 'id', 'allowMenuUrlEdit', 'listed', 'canonicalUrl', 'timeZone', 'ok', 'photos', 'ratingSignals', 'stats', 'inbox', 'specials', 'likes', 'attributes', 'location', 'contact', 'ratingColor', 'shortUrl', 'categories', 'price', 'pageUpdates', 'rating', 'createdAt', 'colors', 'name', 'bestPhoto', 'reasons'])
# {'allowMenuUrlEdit': True,
#  'attributes': {'groups': [{'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '₽₽', 'priceTier': 2}],
#     'name': 'Price',
#     'summary': '₽₽',
#     'type': 'price'},
#    {'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}],
#     'name': 'Reservations',
#     'summary': 'Reservations',
#     'type': 'reservations'},
#    {'count': 5,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}],
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'type': 'payments'},
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.5

# %%
venue_id = '4cb9fa88bac93704486de87c' # ID of Rock Pub
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.5

# %%
venue_id = '4bbb6cbb1261d13a51a9eb98' # ID of  James Cook Pub & Cafe
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.2

# %%
result['response']['venue']['tips']['count']
# Out:
# 278

# %%
## James Cook Pub & Cafe Tips
limit = 300 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c66789a4434b957cf467f29'},
#  'response': {'tips': {'count': 278,
#    'items': [{'agreeCount': 2,
#      'canonicalUrl': 'https://foursquare.com/item/51f7f225498eed55f0ce39ce',
#      'createdAt': 1375203877,
#      'disagreeCount': 0,
#      'id': '51f7f225498eed55f0ce39ce',
#      'lang': 'ru',
#      'likes': {'count': 2,
#       'groups': [{'count': 2,
#         'items': [{'firstName': 'Pavel',
#           'gender': 'male',
#           'id': '6225463',
#           'lastName': 'Parparov',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/PEZZMSB5RD0YZ2TR.jpg'}},
#          {'firstName': 'James Cook',
#           'gender': 'none',
#           'id': '46997366',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/3RSOCUXCOBDGLETK.jpg'},
#           'type': 'chain'}],
#         'type': 'others'}],
#       'summary': '2 likes'},
#      'logView': True,
# ...

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['todo', 'likes', 'photourl', 'user', 'disagreeCount', 'canonicalUrl', 'logView', 'id', 'text', 'agreeCount', 'createdAt', 'lang', 'type', 'photo'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                                                                                                    text  \
# 0  Отличное место со своим велопрокатом! Аренда ретрокрузеров Schwinn всего за 100 Р в час при залоге 10000. Можно оплачивать картой, что очень удобно. В самом пабе — вкусная еда и приятный Guinness.
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  2           0              51f7f225498eed55f0ce39ce  Vladimir
#
#   user.lastName user.gender  user.id
# 0  Luzhbin       male        8746700
